# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/Andarisa/Desktop/world-happiness/2019.csv')



df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ## Nomor 1

# %%
df_1 = df.describe()

df_1.drop(columns = 'Overall rank', inplace=True)

df_1.loc["IQR"] = df_1.loc['75%'] - df_1.loc['25%']

df_1.loc["Range"] = df_1.loc['max'] - df_1.loc['min']

df_1.loc["Variance"] = df_1.loc["std"] ** 2

df_1
# Out:
#                Score  GDP per capita  Social support  Healthy life expectancy  \
# count     156.000000      156.000000      156.000000               156.000000
# mean        5.407096        0.905147        1.208814                 0.725244
# std         1.113120        0.398389        0.299191                 0.242124
# min         2.853000        0.000000        0.000000                 0.000000
# 25%         4.544500        0.602750        1.055750                 0.547750
# 50%         5.379500        0.960000        1.271500                 0.789000
# 75%         6.184500        1.232500        1.452500                 0.881750
# max         7.769000        1.684000        1.624000                 1.141000
# IQR         1.640000        0.629750        0.396750                 0.334000
# Range       4.916000        1.684000        1.624000                 1.141000
# Variance    1.239036        0.158714        0.089515                 0.058624
#
# ...

# %%
df_zscore = df.copy()

df_zscore.drop(columns = ['Overall rank', 'Country or region'], inplace=True)

cols = list(df_zscore.columns)

for col in cols:
    col_zscore = col + '_zscore'
    df_zscore[col_zscore] = (df_zscore[col] - df_zscore[col].mean())/df_zscore[col].std(ddof=1)
df_zscore
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    7.769           1.340           1.587                    0.986
# 1    7.600           1.383           1.573                    0.996
# 2    7.554           1.488           1.582                    1.028
# 3    7.494           1.380           1.624                    1.026
# 4    7.488           1.396           1.522                    0.999
# ..     ...             ...             ...                      ...
# 151  3.334           0.359           0.711                    0.614
# 152  3.231           0.476           0.885                    0.499
# 153  3.203           0.350           0.517                    0.361
# 154  3.083           0.026           0.000                    0.105
# 155  2.853           0.306           0.575                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.596       0.153                      0.393
# ...

# %% [markdown]
# ## Nomor 2

# %%
df_2 = df_1.copy()

df_2.loc['High_Out_IQR'] = df_2.loc['75%'] + (df_2.loc["IQR"] * 1.5)

df_2.loc['Low_Out_IQR'] = df_2.loc['25%'] - (df_2.loc["IQR"] * 1.5)

df_2.loc["High_Out_Zscore"] = df_2.loc["mean"] + (df_2.loc["std"] * 2.5)

df_2.loc["Low_Out_Zscore"] = df_2.loc["mean"] - (df_2.loc["std"] * 2.5)

df_2
# Out:
#                       Score  GDP per capita  Social support  \
# count            156.000000      156.000000      156.000000
# mean               5.407096        0.905147        1.208814
# std                1.113120        0.398389        0.299191
# min                2.853000        0.000000        0.000000
# 25%                4.544500        0.602750        1.055750
# 50%                5.379500        0.960000        1.271500
# 75%                6.184500        1.232500        1.452500
# max                7.769000        1.684000        1.624000
# IQR                1.640000        0.629750        0.396750
# Range              4.916000        1.684000        1.624000
# Variance           1.239036        0.158714        0.089515
# High_Out_IQR       8.644500        2.177125        2.047625
# Low_Out_IQR        2.084500       -0.341875        0.460625
# High_Out_Zscore    8.189896        1.901121        1.956793
# Low_Out_Zscore     2.624296       -0.090826        0.460836
#
# ...

# %% [markdown]
# ### SCORE

# %%
# Low Outlier ,IQR
df[df["Score"] < df_2.loc["Low_Out_IQR","Score"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier, IQR
df[df["Score"] > df_2.loc["High_Out_IQR","Score"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Oulier, Zscore

df[df["Score"] < df_2.loc["Low_Out_Zscore","Score"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Oulier, Zscore

df[df["Score"] > df_2.loc["High_Out_Zscore","Score"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# #### IQR GDP per capita

# %%
# Low Outlier IQR
df[df["GDP per capita"] < df_2.loc["Low_Out_IQR","GDP per capita"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier IQR
df[df["GDP per capita"] > df_2.loc["High_Out_IQR","GDP per capita"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Outlier , Zscore
df[df["GDP per capita"] < df_2.loc["Low_Out_Zscore","GDP per capita"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Outlier , Zscore
df[df["GDP per capita"] > df_2.loc["High_Out_Zscore","GDP per capita"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# ### Social support

# %%
# Low Outlier IQR
df[df["Social support"] < df_2.loc["Low_Out_IQR","Social support"]]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 101           102                     Benin  4.883           0.393
# 144           145                   Burundi  3.775           0.046
# 148           149                     Syria  3.462           0.619
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 101           0.437                    0.397                         0.349
# 144           0.447                    0.380                         0.220
# 148           0.378                    0.440                         0.013
# 154           0.000                    0.105                         0.225
#
#      Generosity  Perceptions of corruption
# 101       0.175                      0.082
# 144       0.176                      0.180
# 148       0.331                      0.141
# 154       0.235                      0.035

# %%
# High Outlier IQR
df[df["Social support"] > df_2.loc["High_Out_IQR","Social support"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Outlier , Zscore
df[df["Social support"] < df_2.loc["Low_Out_Zscore","Social support"]]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 101           102                     Benin  4.883           0.393
# 144           145                   Burundi  3.775           0.046
# 148           149                     Syria  3.462           0.619
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 101           0.437                    0.397                         0.349
# 144           0.447                    0.380                         0.220
# 148           0.378                    0.440                         0.013
# 154           0.000                    0.105                         0.225
#
#      Generosity  Perceptions of corruption
# 101       0.175                      0.082
# 144       0.176                      0.180
# 148       0.331                      0.141
# 154       0.235                      0.035

# %%
# High Outlier , Zscore
df[df["Social support"] > df_2.loc["High_Out_Zscore","Social support"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# ### Healthy life expectancy

# %%
# Low Outlier IQR
df[df["Healthy life expectancy"] < df_2.loc["Low_Out_IQR","Healthy life expectancy"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 134           135         Swaziland  4.212           0.811           1.149
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 134                      0.0                         0.313       0.074
#
#      Perceptions of corruption
# 134                      0.135

# %%
# High Outlier IQR
df[df["Healthy life expectancy"] > df_2.loc["High_Out_IQR","Healthy life expectancy"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Outlier , Zscore
df[df["Healthy life expectancy"] < df_2.loc["Low_Out_Zscore","Healthy life expectancy"]]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 134           135                 Swaziland  4.212           0.811
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 134           1.149                    0.000                         0.313
# 154           0.000                    0.105                         0.225
#
#      Generosity  Perceptions of corruption
# 134       0.074                      0.135
# 154       0.235                      0.035

# %%
# High Outlier , Zscore
df[df["Healthy life expectancy"] > df_2.loc["High_Out_Zscore","Healthy life expectancy"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# ### Freedom to make life choices

# %%
# Low Outlier IQR
df[df["Freedom to make life choices"] < df_2.loc["Low_Out_IQR","Freedom to make life choices"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 153           154       Afghanistan  3.203            0.35           0.517
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 153                    0.361                           0.0       0.158
#
#      Perceptions of corruption
# 153                      0.025

# %%
# High Outlier IQR
df[df["Freedom to make life choices"] > df_2.loc["High_Out_IQR","Freedom to make life choices"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# Low Outlier , Zscore
df[df["Freedom to make life choices"] < df_2.loc["Low_Out_Zscore","Freedom to make life choices"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 146           147             Haiti  3.597           0.323           0.688
# 148           149             Syria  3.462           0.619           0.378
# 153           154       Afghanistan  3.203           0.350           0.517
# 155           156       South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 146                    0.449                         0.026       0.419
# 148                    0.440                         0.013       0.331
# 153                    0.361                         0.000       0.158
# 155                    0.295                         0.010       0.202
#
#      Perceptions of corruption
# 146                      0.110
# 148                      0.141
# 153                      0.025
# 155                      0.091

# %%
# High Outlier , Zscore
df[df["Freedom to make life choices"] > df_2.loc["High_Out_Zscore","Freedom to make life choices"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# ### Generosity

# %%
# Low Outlier IQR
df[df["Generosity"] < df_2.loc["Low_Out_IQR","Generosity"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier IQR
df[df["Generosity"] > df_2.loc["High_Out_IQR","Generosity"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 91             92         Indonesia  5.192           0.931           1.203
# 130           131           Myanmar  4.360           0.710           1.181
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 91                     0.660                         0.491       0.498
# 130                    0.555                         0.525       0.566
#
#      Perceptions of corruption
# 91                       0.028
# 130                      0.172

# %%
# Low Outlier , Zscore
df[df["Generosity"] < df_2.loc["Low_Out_Zscore","Generosity"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier , Zscore
df[df["Generosity"] > df_2.loc["High_Out_Zscore","Generosity"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 91             92         Indonesia  5.192           0.931           1.203
# 130           131           Myanmar  4.360           0.710           1.181
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 91                     0.660                         0.491       0.498
# 130                    0.555                         0.525       0.566
#
#      Perceptions of corruption
# 91                       0.028
# 130                      0.172

# %% [markdown]
# ### Perceptions of corruption

# %%
# Low Outlier IQR
df[df["Perceptions of corruption"] < df_2.loc["Low_Out_IQR","Perceptions of corruption"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier IQR
df[df["Perceptions of corruption"] > df_2.loc["High_Out_IQR","Perceptions of corruption"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.769           1.340           1.587
# 1               2           Denmark  7.600           1.383           1.573
# 2               3            Norway  7.554           1.488           1.582
# 4               5       Netherlands  7.488           1.396           1.522
# 5               6       Switzerland  7.480           1.452           1.526
# 6               7            Sweden  7.343           1.387           1.487
# 7               8       New Zealand  7.307           1.303           1.557
# 8               9            Canada  7.278           1.365           1.505
# 10             11         Australia  7.228           1.372           1.548
# 13             14        Luxembourg  7.090           1.609           1.479
# 15             16           Ireland  7.021           1.499           1.553
# ...

# %%
# Low Outlier , Zscore
df[df["Perceptions of corruption"] < df_2.loc["Low_Out_Zscore","Perceptions of corruption"]]
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
# High Outlier , Zscore
df[df["Perceptions of corruption"] > df_2.loc["High_Out_Zscore","Perceptions of corruption"]]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.769           1.340           1.587
# 1               2           Denmark  7.600           1.383           1.573
# 6               7            Sweden  7.343           1.387           1.487
# 7               8       New Zealand  7.307           1.303           1.557
# 33             34         Singapore  6.262           1.572           1.463
# 151           152            Rwanda  3.334           0.359           0.711
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.986                         0.596       0.153
# 1                      0.996                         0.592       0.252
# 6                      1.009                         0.574       0.267
# 7                      1.026                         0.585       0.330
# 33                     1.141                         0.556       0.271
# ...

# %% [markdown]
# ## Nomor 3

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(20,2))


plt.subplot(171)
plt.hist(df["Score"])
plt.title("Score")

plt.subplot(172)
plt.hist(df["GDP per capita"])
plt.title("GDP per capita")

plt.subplot(173)
plt.hist(df["Social support"])
plt.title("Social support")

plt.subplot(174)
plt.hist(df["Healthy life expectancy"])
plt.title("Healthy life expectancy")


plt.subplot(175)
plt.hist(df["Freedom to make life choices"])
plt.title("Freedom to make life choices")


plt.subplot(176)
plt.hist(df["Generosity"])
plt.title("Generosity")


plt.subplot(177)
plt.hist(df["Perceptions of corruption"])
plt.title("Perceptions of corruption")


plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(20,2))


plt.subplot(171)
plt.boxplot(df["Score"])
plt.title("Score")

plt.subplot(172)
plt.boxplot(df["GDP per capita"])
plt.title("GDP per capita")

plt.subplot(173)
plt.boxplot(df["Social support"])
plt.title("Social support")

plt.subplot(174)
plt.boxplot(df["Healthy life expectancy"])
plt.title("Healthy life expectancy")


plt.subplot(175)
plt.boxplot(df["Freedom to make life choices"])
plt.title("Freedom to make life choices")


plt.subplot(176)
plt.boxplot(df["Generosity"])
plt.title("Generosity")


plt.subplot(177)
plt.boxplot(df["Perceptions of corruption"])
plt.title("Perceptions of corruption")


plt.show()

# %% [markdown]
# ## Nomor 4

# %%
import seaborn as sns

df_3 = df.copy()

df_3.drop(columns ="Overall rank", inplace=True)

sns.heatmap(df_3.corr(method="pearson"), cmap='hot', annot=True)
plt.show()

# %%
sns.heatmap(df_3.corr(method="kendall"), cmap='hot', annot=True)
plt.show()

# %%
sns.heatmap(df_3.corr(method="spearman"), cmap='hot', annot=True)
plt.show()

# %%
sns.heatmap(df_3.cov(), annot=True)
plt.show()

# %% [markdown]
# ## Nomor 5

# %%
df_GNP = df.sort_values(by='GDP per capita', ascending=False)

df_GNP = df_GNP.head(10)

plt.bar(df_GNP["Country or region"], df_GNP["GDP per capita"])

plt.xticks(rotation=90)

plt.title("10 Negara dengan GDP tertinggi")

plt.show()

# %%
df_HLE = df.sort_values(by='Healthy life expectancy', ascending=False)

df_HLE = df_HLE.head(10)

plt.bar(df_HLE["Country or region"], df_HLE['Healthy life expectancy'])

plt.xticks(rotation=90)

plt.title("10 Negara dengan Health Life Expectancy tertinggi")

plt.show()

# %%
df_POC = df.sort_values(by='Perceptions of corruption', ascending=False)

df_POC = df_POC.head(10)

plt.bar(df_POC["Country or region"], df_POC["Perceptions of corruption"])

plt.xticks(rotation=90)

plt.title("10 Negara dengan Perceptions of corruption tertinggi")

plt.show()
